# %%
pwd
# Out:
# 'C:\\Users\\still\\Downloads'

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import math 
import random

dataDir = '/Users/still/Downloads/Measurements - Split/'
runA1 = pd.read_csv(dataDir + '/express/3rd run/runA1.csv', sep=';', decimal= ',')
runA2 = pd.read_csv(dataDir + '/express/3rd run/runA2.csv', sep=';', decimal= ',')
runA3 = pd.read_csv(dataDir + '/express/3rd run/runA3.csv', sep=';', decimal= ',')
runA4 = pd.read_csv(dataDir + '/express/3rd run/runA4.csv', sep=';', decimal= ',')
runA5 = pd.read_csv(dataDir + '/express/3rd run/runA5.csv', sep=';', decimal= ',')
runA6 = pd.read_csv(dataDir + '/express/3rd run/runA6.csv', sep=';', decimal= ',')

# %%
# plot data to check for errors
fig, axes = plt.subplots(2, 6, figsize=(20, 20))
fig.suptitle('Lineplots')
sns.lineplot(ax=axes[0,0], data=runA1, x='minutes', y='SPD33.CH1_Power')
sns.lineplot(ax=axes[0,1], data=runA2, x='minutes', y='SPD33.CH1_Power')
sns.lineplot(ax=axes[0,2], data=runA3, x='minutes', y='SPD33.CH1_Power')
sns.lineplot(ax=axes[0,3], data=runA4, x='minutes', y='SPD33.CH1_Power')
sns.lineplot(ax=axes[0,4], data=runA5, x='minutes', y='SPD33.CH1_Power')
sns.lineplot(ax=axes[0,5], data=runA6, x='minutes', y='SPD33.CH1_Power')
# Out:
# <Axes: xlabel='minutes', ylabel='SPD33.CH1_Power'>

# %%
runA1 = runA1[runA1['SPD33.CH1_Power'] >= 2.0]
runA2 = runA2[runA2['SPD33.CH1_Power'] >= 2.0]
runA3 = runA3[runA3['SPD33.CH1_Power'] >= 2.0]
runA4 = runA4[runA4['SPD33.CH1_Power'] >= 2.0]
runA5 = runA5[runA5['SPD33.CH1_Power'] >= 2.0]
runA6 = runA6[runA6['SPD33.CH1_Power'] >= 2.0]

# plot data to check for errors
fig, axes = plt.subplots(2, 6, figsize=(20, 20))
fig.suptitle('Lineplots')
sns.lineplot(ax=axes[0,0], data=runA1, x='minutes', y='SPD33.CH1_Power')
sns.lineplot(ax=axes[0,1], data=runA2, x='minutes', y='SPD33.CH1_Power')
sns.lineplot(ax=axes[0,2], data=runA3, x='minutes', y='SPD33.CH1_Power')
sns.lineplot(ax=axes[0,3], data=runA4, x='minutes', y='SPD33.CH1_Power')
sns.lineplot(ax=axes[0,4], data=runA5, x='minutes', y='SPD33.CH1_Power')
sns.lineplot(ax=axes[0,5], data=runA6, x='minutes', y='SPD33.CH1_Power')
# Out:
# <Axes: xlabel='minutes', ylabel='SPD33.CH1_Power'>

# %%
areaA1 = np.trapz(runA1['SPD33.CH1_Power'], runA1['minutes'])
areaA2 = np.trapz(runA2['SPD33.CH1_Power'], runA2['minutes'])
areaA3 = np.trapz(runA3['SPD33.CH1_Power'], runA3['minutes'])
areaA4 = np.trapz(runA4['SPD33.CH1_Power'], runA4['minutes'])
areaA5 = np.trapz(runA5['SPD33.CH1_Power'], runA5['minutes'])
areaA6 = np.trapz(runA6['SPD33.CH1_Power'], runA6['minutes'])

areaA1, areaA2, areaA3, areaA4, areaA5, areaA6
# Out:
# (330.63179276699987,
#  329.3918485525001,
#  328.71371287249997,
#  327.9440515925,
#  325.77636276749996,
#  336.21689656999985)

# %%
df = pd.DataFrame([areaA1, areaA2, areaA3, areaA4, areaA5, areaA6])  
#sns.boxplot(data=df)
df['index'] = df.index
df.rename(columns={0:'area'})
df
# Out:
#             0  index
# 0  330.631793      0
# 1  329.391849      1
# 2  328.713713      2
# 3  327.944052      3
# 4  325.776363      4
# 5  336.216897      5

# %%
sns.displot(data=df , kind='kde', height=10, aspect=1.5)
plt.title("Express Server")
plt.xlabel("Energy Consumption")
# Out:
# Text(0.5, 9.444444444444438, 'Energy Consumption')
