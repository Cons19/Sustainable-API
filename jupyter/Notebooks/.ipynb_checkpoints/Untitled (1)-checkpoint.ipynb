# %%
pwd
# Out:
# '/Users/constantin/Documents/University/Master-Thesis/notebooks'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np

dataDir = '/Users/constantin/Documents/University/Master-Thesis/data'
runA1 = pd.read_csv(dataDir + '/results-express.csv', sep=';', decimal= ',')
runA2 = pd.read_csv(dataDir + '/results-nest.csv', sep=';', decimal= ',')
runA3 = pd.read_csv(dataDir + '/results-fastify.csv', sep=';', decimal= ',')
runA4 = pd.read_csv(dataDir + '/results-koa.csv', sep=';', decimal= ',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 import numpy as np
#       7 dataDir = '/Users/constantin/Documents/University/Master-Thesis/data'
# ----> 8 runA1 = pd.read_csv(dataDir + '/results-express.csv', sep=';', decimal= ',')
#       9 runA2 = pd.read_csv(dataDir + '/results-nest.csv', sep=';', decimal= ',')
#      10 runA3 = pd.read_csv(dataDir + '/results-fastify.csv', sep=';', decimal= ',')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
runA1

# %%
# plot data to check for errors
fig, axes = plt.subplots(2, 4, figsize=(20, 20))
fig.suptitle('Lineplots')

sns.lineplot(ax=axes[0,0], data=runA1, x='index', y='SPD33.CH1_Power')
sns.lineplot(ax=axes[0,1], data=runA2, x='index', y='SPD33.CH1_Power')
sns.lineplot(ax=axes[0,2], data=runA3, x='index', y='SPD33.CH1_Power')
sns.lineplot(ax=axes[0,3], data=runA4, x='index', y='SPD33.CH1_Power')

sns.lineplot(ax=axes[1,0], data=runA1, x='index', y='SPD33.CH2_Power')
sns.lineplot(ax=axes[1,1], data=runA2, x='index', y='SPD33.CH2_Power')
sns.lineplot(ax=axes[1,2], data=runA3, x='index', y='SPD33.CH2_Power')
sns.lineplot(ax=axes[1,3], data=runA4, x='index', y='SPD33.CH2_Power')
# Out:
# <Axes: xlabel='index', ylabel='SPD33.CH2_Power'>

# %%
typeA = 'SPD33.CH1_Power'
typeB = 'SPD33.CH2_Power'

data1 = runA1
data2 = runA2
# create a new dataframe with the interesting subset 
df_sampleA = data1[typeA]
df_sampleB = data2[typeB]

def remove_outliers_quantile(data_series):
    data = data_series

    q75, q25 = data.quantile(q=0.75),data.quantile(q=0.25) # np.percentile(data.loc[:,data_column],[75,25])
    intr_qr = q75 - q25

    max = q75 + (1.5 * intr_qr)
    min = q25 - (1.5 * intr_qr)

    count_total = len(data)

    data = data[(data > min) & (data < max)]
    count_wo_outliers = len(data)

    outliers_count = count_total - count_wo_outliers
    
    # remove outliers
    return data

df_sampleA = remove_outliers_quantile(df_sampleA)
print(data1[typeA])
print(df_sampleA)

# plot 
sns.histplot(data=data1[typeA]).set(title='Original Data')
plt.show()
sns.histplot(data=df_sampleA).set(title='Data without Outliers',xlim=(0.015,0.021))
plt.show()
# Out:
# 0        2.0
# 1        2.0
# 2        2.0
# 3        2.0
# 4        2.0
#         ...
# 86569    2.0
# 86570    2.0
# 86571    2.0
# 86572    2.0
# 86573    2.0
# Name: SPD33.CH1_Power, Length: 86574, dtype: float64
# 0        2.0
# 1        2.0
# 2        2.0
# 3        2.0
# 4        2.0
#         ...
# 86569    2.0
# 86570    2.0
# 86571    2.0
# 86572    2.0
# 86573    2.0
# Name: SPD33.CH1_Power, Length: 85427, dtype: float64
