# %%
pwd
# Out:
# 'C:\\Users\\still\\OneDrive\\Diverse\\RUC\\MSc Thesis\\Jupyter'

# %%
import pandas as pd
import numpy as np
from numpy import loadtxt
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import math 
import random
from decimal import Decimal

# %%
repetitions_of_random_sampling = 10000

# %%
def ABtest(setA, setB):

    if setB[0].mean() < setA[0].mean():
        temp = setA
        setA = setB
        setB = temp

    # create a new dataframe with the interesting subset 
    data_set= pd.concat([setA, setB], ignore_index=True, sort=False)
    data_set.reset_index()

    # count the number of samples in each data set 
    count_A = len(setA)
    count_B = len(setB)

    org_mean_diff = setA.mean()-setB.mean()
    if count_A != count_B: print(f"Warning: The data original data sets do not have equally many elements: Data set A has {count_A} elements and Data set B has {count_B} elements")

    total = count_A + count_B
    fact_r = math.factorial(total)

    max_combinations = Decimal(math.factorial(total)) / Decimal((math.factorial(count_A)) * Decimal(math.factorial(total-count_A)))
    max_combinations
    if max_combinations < repetitions_of_random_sampling: 
        print(f"Warning: The number of possible combinations when picking {count_A} elements from {total} elements is {max_combinations} and you have chosen {repetitions_of_random_sampling} repetitions, thus including some repetitions.")

    list_index = list(range(total))
    #list_index

    mean_diffs = []
    for i in range(repetitions_of_random_sampling):
        samples = random.sample(list_index,total)
        sampleA_index = samples[:count_A]
        sampleB_index = samples[count_A:]

        sampleA = data_set.iloc[sampleA_index]
        sampleB = data_set.iloc[sampleB_index]

        mean_diff = sampleA.mean()-sampleB.mean()
        mean_diffs.append(mean_diff)
        #print(mean_diffs)
        print("Working..." + str(i))
    
    mean_diffs = pd.Series(mean_diffs)
    
    return mean_diffs, org_mean_diff

# %%
dataDir = '/Users/still/Downloads/Exported'

expressClientDepartmentsAllPowers = loadtxt(dataDir + '/expressClientDepartmentsAllPowers.txt', unpack=False).tolist()
nestClientDepartmentsAllPowers = loadtxt(dataDir + '/nestClientDepartmentsAllPowers.txt', unpack=False).tolist()
fastifyClientDepartmentsAllPowers = loadtxt(dataDir + '/fastifyClientDepartmentsAllPowers.txt', unpack=False).tolist()
koaClientDepartmentsAllPowers = loadtxt(dataDir + '/koaClientDepartmentsAllPowers.txt', unpack=False).tolist()

expressClientDepartmentsAllPowers = pd.DataFrame(expressClientDepartmentsAllPowers)
nestClientDepartmentsAllPowers = pd.DataFrame(nestClientDepartmentsAllPowers)
fastifyClientDepartmentsAllPowers = pd.DataFrame(fastifyClientDepartmentsAllPowers)
koaClientDepartmentsAllPowers = pd.DataFrame(koaClientDepartmentsAllPowers)

# %%
setA = expressClientDepartmentsAllPowers
setB = nestClientDepartmentsAllPowers
setC = fastifyClientDepartmentsAllPowers
setD = koaClientDepartmentsAllPowers

# A,B
# A,C
# A,D
# B,C
# B,D
# C,D

# %%
res = ABtest(setA, setB)
mean_diffs = res[0]
org_mean_diff = res[1]
# Out:
# ...
# Working...0
# Working...1
# Working...2
# Working...3
# Working...4
# Working...5
# Working...6
# Working...7
# Working...8
# Working...9
# Working...10
# Working...11
# Working...12
# Working...13
# Working...14
# Working...15
# Working...16
# Working...17
# Working...18
# Working...19
# Working...20
# Working...21
# Working...22
# Working...23
# Working...24
# Working...25
# Working...26
# Working...27
# Working...28
# Working...29
# Working...30
# Working...31
# Working...32
# Working...33
# Working...34
# Working...35
# Working...36
# Working...37
# Working...38
# Working...39
# Working...40
# Working...41
# Working...42
# Working...43
# Working...44
# Working...45
# Working...46
# Working...47
# Working...48
# Working...49
# Working...50
# Working...51
# Working...52
# Working...53
# Working...54
# Working...55
# Working...56
# Working...57
# Working...58
# Working...59
# Working...60
# Working...61
# Working...62
# Working...63
# Working...64
# Working...65
# Working...66
# ...

# %%
mean_diffs = pd.Series(mean_diffs)
my_array = []
    
for i in range (0, len(mean_diffs)):
    my_array.append(mean_diffs[i][0])
    
counter = 0

for i in mean_diffs:
    if i[0] <= org_mean_diff[0]:
        counter += 1
        
empirical_p = counter / repetitions_of_random_sampling
    
empirical_p
#empirical_p = np.count_nonzero(pd.Series(mean_diffs) <= org_mean_diff) / repetitions_of_random_sampling
# Out:
# 0.0032

# %%
# evaluate the histogram
fig, ax = plt.subplots(figsize=(12, 6))
values, base = np.histogram(my_array, bins=40)
plt.plot(base[:-1], values, c='gray')
# a red line indicating the original difference between the averages of the original samples 
plt.axvline(x = org_mean_diff[0], color = 'red', label = 'difference between original samples')
plt.show()

# %%
# conclusion:
print(f"If the empirical p-value is 0 ,it means that none of the {repetitions_of_random_sampling} permuted samples "+
       f"resulted in a difference of {org_mean_diff[0]} or lower. This is only an approximation. "+
       "The probability of getting a difference in that range is not 0, but it is very small,"+
       "according to our simulation. Therefore we can reject the null hypothesis.")
# Out:
# If the empirical p-value is 0 ,it means that none of the 10000 permuted samples resulted in a difference of -0.011985205721729564 or lower. This is only an approximation. The probability of getting a difference in that range is not 0, but it is very small,according to our simulation. Therefore we can reject the null hypothesis.

# %%
res = ABtest(setA, setC)
mean_diffs = res[0]
org_mean_diff = res[1]
# Out:
# ...
# Working...0
# Working...1
# Working...2
# Working...3
# Working...4
# Working...5
# Working...6
# Working...7
# Working...8
# Working...9
# Working...10
# Working...11
# Working...12
# Working...13
# Working...14
# Working...15
# Working...16
# Working...17
# Working...18
# Working...19
# Working...20
# Working...21
# Working...22
# Working...23
# Working...24
# Working...25
# Working...26
# Working...27
# Working...28
# Working...29
# Working...30
# Working...31
# Working...32
# Working...33
# Working...34
# Working...35
# Working...36
# Working...37
# Working...38
# Working...39
# Working...40
# Working...41
# Working...42
# Working...43
# Working...44
# Working...45
# Working...46
# Working...47
# Working...48
# Working...49
# Working...50
# Working...51
# Working...52
# Working...53
# Working...54
# Working...55
# Working...56
# Working...57
# Working...58
# Working...59
# Working...60
# Working...61
# Working...62
# Working...63
# Working...64
# Working...65
# Working...66
# ...

# %%
mean_diffs = pd.Series(mean_diffs)
my_array = []
    
for i in range (0, len(mean_diffs)):
    my_array.append(mean_diffs[i][0])
    
counter = 0

for i in mean_diffs:
    if i[0] <= org_mean_diff[0]:
        counter += 1
        
empirical_p = counter / repetitions_of_random_sampling
    
empirical_p
#empirical_p = np.count_nonzero(pd.Series(mean_diffs) <= org_mean_diff) / repetitions_of_random_sampling
# Out:
# 0.0132

# %%
# evaluate the histogram
fig, ax = plt.subplots(figsize=(12, 6))
values, base = np.histogram(my_array, bins=40)
plt.plot(base[:-1], values, c='gray')
# a red line indicating the original difference between the averages of the original samples 
plt.axvline(x = org_mean_diff[0], color = 'red', label = 'difference between original samples')
plt.show()

# %%
# conclusion:
print(f"If the empirical p-value is 0 ,it means that none of the {repetitions_of_random_sampling} permuted samples "+
       f"resulted in a difference of {org_mean_diff[0]} or lower. This is only an approximation. "+
       "The probability of getting a difference in that range is not 0, but it is very small,"+
       "according to our simulation. Therefore we can reject the null hypothesis.")
# Out:
# If the empirical p-value is 0 ,it means that none of the 10000 permuted samples resulted in a difference of -0.010044447614271146 or lower. This is only an approximation. The probability of getting a difference in that range is not 0, but it is very small,according to our simulation. Therefore we can reject the null hypothesis.

# %%
res = ABtest(setA, setD)
mean_diffs = res[0]
org_mean_diff = res[1]
# Out:
# ...
# Working...0
# Working...1
# Working...2
# Working...3
# Working...4
# Working...5
# Working...6
# Working...7
# Working...8
# Working...9
# Working...10
# Working...11
# Working...12
# Working...13
# Working...14
# Working...15
# Working...16
# Working...17
# Working...18
# Working...19
# Working...20
# Working...21
# Working...22
# Working...23
# Working...24
# Working...25
# Working...26
# Working...27
# Working...28
# Working...29
# Working...30
# Working...31
# Working...32
# Working...33
# Working...34
# Working...35
# Working...36
# Working...37
# Working...38
# Working...39
# Working...40
# Working...41
# Working...42
# Working...43
# Working...44
# Working...45
# Working...46
# Working...47
# Working...48
# Working...49
# Working...50
# Working...51
# Working...52
# Working...53
# Working...54
# Working...55
# Working...56
# Working...57
# Working...58
# Working...59
# Working...60
# Working...61
# Working...62
# Working...63
# Working...64
# Working...65
# Working...66
# ...

# %%
mean_diffs = pd.Series(mean_diffs)
my_array = []
    
for i in range (0, len(mean_diffs)):
    my_array.append(mean_diffs[i][0])
    
counter = 0

for i in mean_diffs:
    if i[0] <= org_mean_diff[0]:
        counter += 1
        
empirical_p = counter / repetitions_of_random_sampling
    
empirical_p
#empirical_p = np.count_nonzero(pd.Series(mean_diffs) <= org_mean_diff) / repetitions_of_random_sampling
# Out:
# 0.1269

# %%
# evaluate the histogram
fig, ax = plt.subplots(figsize=(12, 6))
values, base = np.histogram(my_array, bins=40)
plt.plot(base[:-1], values, c='gray')
# a red line indicating the original difference between the averages of the original samples 
plt.axvline(x = org_mean_diff[0], color = 'red', label = 'difference between original samples')
plt.show()

# %%
# conclusion:
print(f"If the empirical p-value is 0 ,it means that none of the {repetitions_of_random_sampling} permuted samples "+
       f"resulted in a difference of {org_mean_diff[0]} or lower. This is only an approximation. "+
       "The probability of getting a difference in that range is not 0, but it is very small,"+
       "according to our simulation. Therefore we can reject the null hypothesis.")
# Out:
# If the empirical p-value is 0 ,it means that none of the 10000 permuted samples resulted in a difference of -0.005124907654794786 or lower. This is only an approximation. The probability of getting a difference in that range is not 0, but it is very small,according to our simulation. Therefore we can reject the null hypothesis.

# %%
res = ABtest(setB, setC)
mean_diffs = res[0]
org_mean_diff = res[1]
# Out:
# ...
# Working...0
# Working...1
# Working...2
# Working...3
# Working...4
# Working...5
# Working...6
# Working...7
# Working...8
# Working...9
# Working...10
# Working...11
# Working...12
# Working...13
# Working...14
# Working...15
# Working...16
# Working...17
# Working...18
# Working...19
# Working...20
# Working...21
# Working...22
# Working...23
# Working...24
# Working...25
# Working...26
# Working...27
# Working...28
# Working...29
# Working...30
# Working...31
# Working...32
# Working...33
# Working...34
# Working...35
# Working...36
# Working...37
# Working...38
# Working...39
# Working...40
# Working...41
# Working...42
# Working...43
# Working...44
# Working...45
# Working...46
# Working...47
# Working...48
# Working...49
# Working...50
# Working...51
# Working...52
# Working...53
# Working...54
# Working...55
# Working...56
# Working...57
# Working...58
# Working...59
# Working...60
# Working...61
# Working...62
# Working...63
# Working...64
# Working...65
# Working...66
# ...

# %%
mean_diffs = pd.Series(mean_diffs)
my_array = []
    
for i in range (0, len(mean_diffs)):
    my_array.append(mean_diffs[i][0])
    
counter = 0

for i in mean_diffs:
    if i[0] <= org_mean_diff[0]:
        counter += 1
        
empirical_p = counter / repetitions_of_random_sampling
    
empirical_p
#empirical_p = np.count_nonzero(pd.Series(mean_diffs) <= org_mean_diff) / repetitions_of_random_sampling
# Out:
# 0.0

# %%
# evaluate the histogram
fig, ax = plt.subplots(figsize=(12, 6))
values, base = np.histogram(my_array, bins=40)
plt.plot(base[:-1], values, c='gray')
# a red line indicating the original difference between the averages of the original samples 
plt.axvline(x = org_mean_diff[0], color = 'red', label = 'difference between original samples')
plt.show()

# %%
# conclusion:
print(f"If the empirical p-value is 0 ,it means that none of the {repetitions_of_random_sampling} permuted samples "+
       f"resulted in a difference of {org_mean_diff[0]} or lower. This is only an approximation. "+
       "The probability of getting a difference in that range is not 0, but it is very small,"+
       "according to our simulation. Therefore we can reject the null hypothesis.")
# Out:
# If the empirical p-value is 0 ,it means that none of the 10000 permuted samples resulted in a difference of -0.02202965333600071 or lower. This is only an approximation. The probability of getting a difference in that range is not 0, but it is very small,according to our simulation. Therefore we can reject the null hypothesis.

# %%
res = ABtest(setB, setD)
mean_diffs = res[0]
org_mean_diff = res[1]
# Out:
# ...
# Working...0
# Working...1
# Working...2
# Working...3
# Working...4
# Working...5
# Working...6
# Working...7
# Working...8
# Working...9
# Working...10
# Working...11
# Working...12
# Working...13
# Working...14
# Working...15
# Working...16
# Working...17
# Working...18
# Working...19
# Working...20
# Working...21
# Working...22
# Working...23
# Working...24
# Working...25
# Working...26
# Working...27
# Working...28
# Working...29
# Working...30
# Working...31
# Working...32
# Working...33
# Working...34
# Working...35
# Working...36
# Working...37
# Working...38
# Working...39
# Working...40
# Working...41
# Working...42
# Working...43
# Working...44
# Working...45
# Working...46
# Working...47
# Working...48
# Working...49
# Working...50
# Working...51
# Working...52
# Working...53
# Working...54
# Working...55
# Working...56
# Working...57
# Working...58
# Working...59
# Working...60
# Working...61
# Working...62
# Working...63
# Working...64
# Working...65
# Working...66
# ...

# %%
mean_diffs = pd.Series(mean_diffs)
my_array = []
    
for i in range (0, len(mean_diffs)):
    my_array.append(mean_diffs[i][0])
    
counter = 0

for i in mean_diffs:
    if i[0] <= org_mean_diff[0]:
        counter += 1
        
empirical_p = counter / repetitions_of_random_sampling
    
empirical_p
#empirical_p = np.count_nonzero(pd.Series(mean_diffs) <= org_mean_diff) / repetitions_of_random_sampling
# Out:
# 0.0001

# %%
# evaluate the histogram
fig, ax = plt.subplots(figsize=(12, 6))
values, base = np.histogram(my_array, bins=40)
plt.plot(base[:-1], values, c='gray')
# a red line indicating the original difference between the averages of the original samples 
plt.axvline(x = org_mean_diff[0], color = 'red', label = 'difference between original samples')
plt.show()

# %%
# conclusion:
print(f"If the empirical p-value is 0 ,it means that none of the {repetitions_of_random_sampling} permuted samples "+
       f"resulted in a difference of {org_mean_diff[0]} or lower. This is only an approximation. "+
       "The probability of getting a difference in that range is not 0, but it is very small,"+
       "according to our simulation. Therefore we can reject the null hypothesis.")
# Out:
# If the empirical p-value is 0 ,it means that none of the 10000 permuted samples resulted in a difference of -0.01711011337652435 or lower. This is only an approximation. The probability of getting a difference in that range is not 0, but it is very small,according to our simulation. Therefore we can reject the null hypothesis.

# %%
res = ABtest(setC, setD)
mean_diffs = res[0]
org_mean_diff = res[1]
# Out:
# ...
# Working...0
# Working...1
# Working...2
# Working...3
# Working...4
# Working...5
# Working...6
# Working...7
# Working...8
# Working...9
# Working...10
# Working...11
# Working...12
# Working...13
# Working...14
# Working...15
# Working...16
# Working...17
# Working...18
# Working...19
# Working...20
# Working...21
# Working...22
# Working...23
# Working...24
# Working...25
# Working...26
# Working...27
# Working...28
# Working...29
# Working...30
# Working...31
# Working...32
# Working...33
# Working...34
# Working...35
# Working...36
# Working...37
# Working...38
# Working...39
# Working...40
# Working...41
# Working...42
# Working...43
# Working...44
# Working...45
# Working...46
# Working...47
# Working...48
# Working...49
# Working...50
# Working...51
# Working...52
# Working...53
# Working...54
# Working...55
# Working...56
# Working...57
# Working...58
# Working...59
# Working...60
# Working...61
# Working...62
# Working...63
# Working...64
# Working...65
# Working...66
# ...

# %%
mean_diffs = pd.Series(mean_diffs)
my_array = []
    
for i in range (0, len(mean_diffs)):
    my_array.append(mean_diffs[i][0])
    
counter = 0

for i in mean_diffs:
    if i[0] <= org_mean_diff[0]:
        counter += 1
        
empirical_p = counter / repetitions_of_random_sampling
    
empirical_p
#empirical_p = np.count_nonzero(pd.Series(mean_diffs) <= org_mean_diff) / repetitions_of_random_sampling
# Out:
# 0.1363

# %%
# evaluate the histogram
fig, ax = plt.subplots(figsize=(12, 6))
values, base = np.histogram(my_array, bins=40)
plt.plot(base[:-1], values, c='gray')
# a red line indicating the original difference between the averages of the original samples 
plt.axvline(x = org_mean_diff[0], color = 'red', label = 'difference between original samples')
plt.show()

# %%
# conclusion:
print(f"If the empirical p-value is 0 ,it means that none of the {repetitions_of_random_sampling} permuted samples "+
       f"resulted in a difference of {org_mean_diff[0]} or lower. This is only an approximation. "+
       "The probability of getting a difference in that range is not 0, but it is very small,"+
       "according to our simulation. Therefore we can reject the null hypothesis.")
# Out:
# If the empirical p-value is 0 ,it means that none of the 10000 permuted samples resulted in a difference of -0.00491953995947636 or lower. This is only an approximation. The probability of getting a difference in that range is not 0, but it is very small,according to our simulation. Therefore we can reject the null hypothesis.
