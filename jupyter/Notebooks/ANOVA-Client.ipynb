# %%
pwd
# Out:
# 'C:\\Users\\still\\OneDrive\\Diverse\\RUC\\MSc Thesis\\Jupyter'

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import math 
import random

dataDir = '/Users/still/Downloads/Exported'
experimentData1 = pd.read_csv(dataDir + '/expressClientArea.csv', sep=',', decimal= ',')
experimentData2 = pd.read_csv(dataDir + '/nestClientArea.csv', sep=',', decimal= ',')
experimentData3 = pd.read_csv(dataDir + '/fastifyClientArea.csv', sep=',', decimal= ',')
experimentData4 = pd.read_csv(dataDir + '/koaClientArea.csv', sep=',', decimal= ',')

experimentData1
# Out:
#                  area  run
# 0  323.78020531404997    0
# 1   323.4122420225001    1
# 2  323.28884345250003    2
# 3      324.9205727225    3
# 4   324.4441954325001    4
# 5  334.62129487499993    5

# %%
experimentData1['experiment']='Express'
experimentData2['experiment']='Nest'
experimentData3['experiment']='Fastify'
experimentData4['experiment']='Koa'

pdList1 = [experimentData1, experimentData2, experimentData3, experimentData4]
areasCollected = pd.concat(pdList1, ignore_index=True)
areasCollected = areasCollected.drop(columns="run")
areasCollected['index']=list(range(len(areasCollected)))
areasCollected = areasCollected[['index', 'experiment', 'area']]

pdList1
# Out:
# [                 area  run experiment
#  0  323.78020531404997    0    Express
#  1   323.4122420225001    1    Express
#  2  323.28884345250003    2    Express
#  3      324.9205727225    3    Express
#  4   324.4441954325001    4    Express
#  5  334.62129487499993    5    Express,
#                   area  run experiment
#  0  324.19431825665004    0       Nest
#  1      323.6952132925    1       Nest
#  2  323.67662955749984    2       Nest
#  3   324.3585645800001    3       Nest
#  4   324.3543243550002    4       Nest
#  5  334.67405720000016    5       Nest,
#                   area  run experiment
#  0      323.4200116193    0    Fastify
#  1   323.2737737724999    1    Fastify
#  2       323.191584965    2    Fastify
#  3   324.4733283674999    3    Fastify
#  4        324.28082677    4    Fastify
#  5  334.32452591000015    5    Fastify,
#                   area  run experiment
#  0      323.5053399681    0        Koa
#  1  323.27574287249996    1        Koa
# ...

# %%
my_pal = {"Express":"#F7CE76", "Nest":"#EEB8C5", "Fastify":"#98D4BB", "Koa":"#9AC8EB"}

areasCollected['area'] = areasCollected['area'].astype('float')

sns.set(rc={'figure.figsize':(20,5)})
sns.set_context("talk")
sns.boxplot(data=areasCollected, y='experiment' , x='area', palette=my_pal)
plt.title("Box Plot All Experiments Client")
plt.xlabel("Energy Consumption (J)")
plt.ylabel("Experiment Type")
# Out:
# Text(0, 0.5, 'Experiment Type')
