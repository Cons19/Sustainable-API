# %%
pwd
# Out:
# 'C:\\Users\\still\\OneDrive\\Diverse\\RUC\\MSc Thesis\\Jupyter'

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import math 
import random

# %%
################ AREA UNDER THE CURVE ################

# %%
################ EMPLOYEES ################

# %%
dataDir = '/Users/still/Downloads/Exported'

# Areas
expressServerEmployeesAreas = pd.read_csv(dataDir + '/expressServerEmployeesAreas.csv', sep=',', decimal= ',')
nestServerEmployeesAreas = pd.read_csv(dataDir + '/nestServerEmployeesAreas.csv', sep=',', decimal= ',')
fastifyServerEmployeesAreas = pd.read_csv(dataDir + '/fastifyServerEmployeesAreas.csv', sep=',', decimal= ',')
koaServerEmployeesAreas = pd.read_csv(dataDir + '/koaServerEmployeesAreas.csv', sep=',', decimal= ',')

expressClientEmployeesAreas = pd.read_csv(dataDir + '/expressClientEmployeesAreas.csv', sep=',', decimal= ',')
nestClientEmployeesAreas = pd.read_csv(dataDir + '/nestClientEmployeesAreas.csv', sep=',', decimal= ',')
fastifyClientEmployeesAreas = pd.read_csv(dataDir + '/fastifyClientEmployeesAreas.csv', sep=',', decimal= ',')
koaClientEmployeesAreas = pd.read_csv(dataDir + '/koaClientEmployeesAreas.csv', sep=',', decimal= ',')

my_pal = {"Express":"#4287f5", "Nest":"#ff9f0f", "Fastify":"#03a341", "Koa":"#fa344f"}
my_pal2 = ["#4287f5", "#ff9f0f", "#03a341", "#fa344f"]

expressServerEmployeesAreas
# Out:
#                   area  run
# 0    68.84999999999998    1
# 1    68.64999999999999    2
# 2    70.89999999999998    3
# 3    68.39999999999998    4
# 4    68.29999999999998    5
# 5                 68.6    6
# 6    68.64999999999998    7
# 7    68.39999999999999    8
# 8    67.94999999999999    9
# 9    68.39999999999999   10
# 10   66.24999999999999   11
# 11   65.99999999999999   12
# 12   65.14999999999999   13
# 13   68.24999999999999   14
# 14                65.3   15
# 15   67.69999999999999   16
# 16   67.64999999999999   17
# 17   65.89999999999999   18
# 18               67.55   19
# 19   67.39999999999999   20
# 20   59.24999999999998   21
# 21  61.449999999999996   22
# 22  63.349999999999994   23
# 23   63.14999999999999   24
# 24                63.3   25
# 25   60.34999999999998   26
# 26  62.949999999999996   27
# 27   62.79999999999999   28
# 28                61.3   29
# 29                58.3   30
# 30                58.8   31

# %%
for i in range (0, 31):
    expressServerEmployeesAreas['area'][i] = round(float(expressServerEmployeesAreas['area'][i]),1)
    nestServerEmployeesAreas['area'][i] = round(float(nestServerEmployeesAreas['area'][i]),1)
    fastifyServerEmployeesAreas['area'][i] = round(float(fastifyServerEmployeesAreas['area'][i]),1)
    koaServerEmployeesAreas['area'][i] = round(float(koaServerEmployeesAreas['area'][i]),1)
    expressClientEmployeesAreas['area'][i] = round(float(expressClientEmployeesAreas['area'][i]),1)
    nestClientEmployeesAreas['area'][i] = round(float(nestClientEmployeesAreas['area'][i]),1)
    fastifyClientEmployeesAreas['area'][i] = round(float(fastifyClientEmployeesAreas['area'][i]),1)
    koaClientEmployeesAreas['area'][i] = round(float(koaClientEmployeesAreas['area'][i]),1)
    
expressServerEmployeesAreas
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_20164\3463169129.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expressServerEmployeesAreas['area'][i] = round(float(expressServerEmployeesAreas['area'][i]),1)
# C:\Users\still\AppData\Local\Temp\ipykernel_20164\3463169129.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nestServerEmployeesAreas['area'][i] = round(float(nestServerEmployeesAreas['area'][i]),1)
# C:\Users\still\AppData\Local\Temp\ipykernel_20164\3463169129.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
m1c = expressServerEmployeesAreas['area'].mean()
m2c = nestServerEmployeesAreas['area'].mean()
m3c = fastifyServerEmployeesAreas['area'].mean()
m4c = koaServerEmployeesAreas['area'].mean()
m1s = expressClientEmployeesAreas['area'].mean()
m2s = nestClientEmployeesAreas['area'].mean()
m3s = fastifyClientEmployeesAreas['area'].mean()
m4s = koaClientEmployeesAreas['area'].mean()

d = {'experiment': ["Express", "Nest", "Fastify", "Koa"],
     'meanAreaServer': [m1c, m2c, m3c, m4c],
     'meanAreaClient': [m1s, m2s, m3s, m4s]}
df = pd.DataFrame(data=d)

# %%
df2 = df
df2 = pd.melt(df2, id_vars="experiment", var_name="means", value_name="Mean area")
df2
# Out:
#   experiment           means  Mean area
# 0    Express  meanAreaServer  65.435484
# 1       Nest  meanAreaServer  79.435484
# 2    Fastify  meanAreaServer  68.061290
# 3        Koa  meanAreaServer  65.122581
# 4    Express  meanAreaClient  64.825806
# 5       Nest  meanAreaClient  76.835484
# 6    Fastify  meanAreaClient  68.167742
# 7        Koa  meanAreaClient  64.416129

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.set_context("talk")
ax = sns.barplot(x="experiment", y="Mean area", hue="means",
            palette={'meanAreaServer': 'white', 'meanAreaClient': 'black'}, data=df2)
for bar_group, desaturate_value in zip(ax.containers, [0.5, 1]):
    for bar, color in zip(bar_group, my_pal2):
        bar.set_facecolor(sns.desaturate(color, desaturate_value))

hatches = ["///", ""]
for bars, hatch in zip(ax.containers, hatches):
    for bar in bars:
        bar.set_hatch(hatch)
        
plt.title("Energy consumption Client vs Server (Employees)")
plt.xlabel("Experiment Type")
plt.ylabel("Energy Consumption (J)")

handles, labels = ax.get_legend_handles_labels()

from matplotlib.legend_handler import HandlerTuple
ax.legend(handles=[tuple(bar_group) for bar_group in ax.containers],
          labels=['Server', 'Client'],
          handlelength=4, handler_map={tuple: HandlerTuple(ndivide=None, pad=0.1)})

# Add values on top of the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.show()

# %%
################ DEPARTMENTS ################

# %%
# Areas
expressServerDepartmentsAreas = pd.read_csv(dataDir + '/expressServerDepartmentsAreas.csv', sep=',', decimal= ',')
nestServerDepartmentsAreas = pd.read_csv(dataDir + '/nestServerDepartmentsAreas.csv', sep=',', decimal= ',')
fastifyServerDepartmentsAreas = pd.read_csv(dataDir + '/fastifyServerDepartmentsAreas.csv', sep=',', decimal= ',')
koaServerDepartmentsAreas = pd.read_csv(dataDir + '/koaServerDepartmentsAreas.csv', sep=',', decimal= ',')

expressClientDepartmentsAreas = pd.read_csv(dataDir + '/expressClientDepartmentsAreas.csv', sep=',', decimal= ',')
nestClientDepartmentsAreas = pd.read_csv(dataDir + '/nestClientDepartmentsAreas.csv', sep=',', decimal= ',')
fastifyClientDepartmentsAreas = pd.read_csv(dataDir + '/fastifyClientDepartmentsAreas.csv', sep=',', decimal= ',')
koaClientDepartmentsAreas = pd.read_csv(dataDir + '/koaClientDepartmentsAreas.csv', sep=',', decimal= ',')

my_pal = {"Express":"#4287f5", "Nest":"#ff9f0f", "Fastify":"#03a341", "Koa":"#fa344f"}
my_pal2 = ["#4287f5", "#ff9f0f", "#03a341", "#fa344f"]

expressClientDepartmentsAreas
# Out:
#                   area  run
# 0               143.75    1
# 1               142.25    2
# 2               141.95    3
# 3   143.45000000000002    4
# 4   144.20000000000005    5
# 5   141.14999999999998    6
# 6               145.05    7
# 7                143.4    8
# 8   146.14999999999998    9
# 9               150.05   10
# 10               144.2   11
# 11  143.29999999999998   12
# 12              145.15   13
# 13               140.2   14
# 14               138.3   15
# 15              147.15   16
# 16              139.65   17
# 17              147.25   18
# 18  142.20000000000002   19
# 19               142.2   20
# 20               141.9   21
# 21               141.1   22
# 22               143.8   23
# 23  144.70000000000002   24
# 24              142.15   25
# 25  141.00000000000003   26
# 26               139.0   27
# 27  146.45000000000002   28
# 28               140.1   29
# 29  138.54999999999998   30
# 30  146.59999999999997   31

# %%
for i in range (0, 31):
    expressServerDepartmentsAreas['area'][i] = round(float(expressServerDepartmentsAreas['area'][i]),1)
    nestServerDepartmentsAreas['area'][i] = round(float(nestServerDepartmentsAreas['area'][i]),1)
    fastifyServerDepartmentsAreas['area'][i] = round(float(fastifyServerDepartmentsAreas['area'][i]),1)
    koaServerDepartmentsAreas['area'][i] = round(float(koaServerDepartmentsAreas['area'][i]),1)
    expressClientDepartmentsAreas['area'][i] = round(float(expressClientDepartmentsAreas['area'][i]),1)
    nestClientDepartmentsAreas['area'][i] = round(float(nestClientDepartmentsAreas['area'][i]),1)
    fastifyClientDepartmentsAreas['area'][i] = round(float(fastifyClientDepartmentsAreas['area'][i]),1)
    koaClientDepartmentsAreas['area'][i] = round(float(koaClientDepartmentsAreas['area'][i]),1)
    
expressServerDepartmentsAreas
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_20164\2965562771.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expressServerDepartmentsAreas['area'][i] = round(float(expressServerDepartmentsAreas['area'][i]),1)
# C:\Users\still\AppData\Local\Temp\ipykernel_20164\2965562771.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nestServerDepartmentsAreas['area'][i] = round(float(nestServerDepartmentsAreas['area'][i]),1)
# C:\Users\still\AppData\Local\Temp\ipykernel_20164\2965562771.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
m1c = expressServerDepartmentsAreas['area'].mean()
m2c = nestServerDepartmentsAreas['area'].mean()
m3c = fastifyServerDepartmentsAreas['area'].mean()
m4c = koaServerDepartmentsAreas['area'].mean()
m1s = expressClientDepartmentsAreas['area'].mean()
m2s = nestClientDepartmentsAreas['area'].mean()
m3s = fastifyClientDepartmentsAreas['area'].mean()
m4s = koaClientDepartmentsAreas['area'].mean()

d = {'experiment': ["Express", "Nest", "Fastify", "Koa"],
     'meanAreaServer': [m1c, m2c, m3c, m4c],
     'meanAreaClient': [m1s, m2s, m3s, m4s]}
df = pd.DataFrame(data=d)

# %%
df3 = df
df3 = pd.melt(df3, id_vars="experiment", var_name="means", value_name="Mean area")
df3
# Out:
#   experiment           means   Mean area
# 0    Express  meanAreaServer  145.161290
# 1       Nest  meanAreaServer  147.848387
# 2    Fastify  meanAreaServer  138.487097
# 3        Koa  meanAreaServer  145.454839
# 4    Express  meanAreaClient  143.112903
# 5       Nest  meanAreaClient  144.506452
# 6    Fastify  meanAreaClient  136.232258
# 7        Koa  meanAreaClient  143.193548

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.set_context("talk")
ax = sns.barplot(x="experiment", y="Mean area", hue="means",
            palette={'meanAreaServer': 'white', 'meanAreaClient': 'black'}, data=df3)
for bar_group, desaturate_value in zip(ax.containers, [0.5, 1]):
    for bar, color in zip(bar_group, my_pal2):
        bar.set_facecolor(sns.desaturate(color, desaturate_value))

hatches = ["///", ""]
for bars, hatch in zip(ax.containers, hatches):
    for bar in bars:
        bar.set_hatch(hatch)
        
plt.title("Energy consumption Server vs Client (Departments)")
plt.xlabel("Experiment Type")
plt.ylabel("Energy Consumption (J)")

handles, labels = ax.get_legend_handles_labels()

from matplotlib.legend_handler import HandlerTuple
ax.legend(handles=[tuple(bar_group) for bar_group in ax.containers],
          labels=['Server', 'Client'],
            handlelength=4, handler_map={tuple: HandlerTuple(ndivide=None, pad=0.1)},  loc='lower right')

# Add values on top of the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.show()

# %%
################ POWER ################

# %%
################ EMPLOYEES ################

# %%
dataDir = '/Users/still/Downloads/Exported'

# Powers
expressServerEmployeesMeanPowers = pd.read_csv(dataDir + '/expressServerEmployeesMeanPowers.csv', sep=',', decimal= ',')
nestServerEmployeesMeanPowers = pd.read_csv(dataDir + '/nestServerEmployeesMeanPowers.csv', sep=',', decimal= ',')
fastifyServerEmployeesMeanPowers = pd.read_csv(dataDir + '/fastifyServerEmployeesMeanPowers.csv', sep=',', decimal= ',')
koaServerEmployeesMeanPowers = pd.read_csv(dataDir + '/koaServerEmployeesMeanPowers.csv', sep=',', decimal= ',')

expressClientEmployeesMeanPowers = pd.read_csv(dataDir + '/expressClientEmployeesMeanPowers.csv', sep=',', decimal= ',')
nestClientEmployeesMeanPowers = pd.read_csv(dataDir + '/nestClientEmployeesMeanPowers.csv', sep=',', decimal= ',')
fastifyClientEmployeesMeanPowers = pd.read_csv(dataDir + '/fastifyClientEmployeesMeanPowers.csv', sep=',', decimal= ',')
koaClientEmployeesMeanPowers = pd.read_csv(dataDir + '/koaClientEmployeesMeanPowers.csv', sep=',', decimal= ',')

my_pal = {"Express":"#4287f5", "Nest":"#ff9f0f", "Fastify":"#03a341", "Koa":"#fa344f"}
my_pal2 = ["#4287f5", "#ff9f0f", "#03a341", "#fa344f"]

expressServerEmployeesMeanPowers
# Out:
#                meanPow  run
# 0   2.2949999999999995    1
# 1    2.288333333333333    2
# 2   2.2870967741935475    3
# 3   2.2799999999999994    4
# 4    2.276666666666666    5
# 5   2.2866666666666666    6
# 6   2.2883333333333327    7
# 7                 2.28    8
# 8   2.2649999999999997    9
# 9                 2.28   10
# 10   2.284482758620689   11
# 11   2.275862068965517   12
# 12  2.2465517241379307   13
# 13  2.2749999999999995   14
# 14  2.2517241379310344   15
# 15  2.2566666666666664   16
# 16               2.255   17
# 17   2.272413793103448   18
# 18  2.2516666666666665   19
# 19  2.2466666666666666   20
# 20  2.1944444444444438   21
# 21  2.2759259259259257   22
# 22  2.2624999999999997   23
# 23  2.2553571428571426   24
# 24  2.2607142857142857   25
# 25  2.2351851851851845   26
# 26  2.2482142857142855   27
# 27  2.2428571428571424   28
# 28    2.27037037037037   29
# 29  2.2423076923076923   30
# 30  2.2615384615384615   31

# %%
for i in range (0, 31):
    expressServerEmployeesMeanPowers['meanPow'][i] = round(float(expressServerEmployeesMeanPowers['meanPow'][i]),1)
    nestServerEmployeesMeanPowers['meanPow'][i] = round(float(nestServerEmployeesMeanPowers['meanPow'][i]),1)
    fastifyServerEmployeesMeanPowers['meanPow'][i] = round(float(fastifyServerEmployeesMeanPowers['meanPow'][i]),1)
    koaServerEmployeesMeanPowers['meanPow'][i] = round(float(koaServerEmployeesMeanPowers['meanPow'][i]),1)
    expressClientEmployeesMeanPowers['meanPow'][i] = round(float(expressClientEmployeesMeanPowers['meanPow'][i]),1)
    nestClientEmployeesMeanPowers['meanPow'][i] = round(float(nestClientEmployeesMeanPowers['meanPow'][i]),1)
    fastifyClientEmployeesMeanPowers['meanPow'][i] = round(float(fastifyClientEmployeesMeanPowers['meanPow'][i]),1)
    koaClientEmployeesMeanPowers['meanPow'][i] = round(float(koaClientEmployeesMeanPowers['meanPow'][i]),1)
    
expressServerEmployeesMeanPowers
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_20164\2929271984.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expressServerEmployeesMeanPowers['meanPow'][i] = round(float(expressServerEmployeesMeanPowers['meanPow'][i]),1)
# C:\Users\still\AppData\Local\Temp\ipykernel_20164\2929271984.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nestServerEmployeesMeanPowers['meanPow'][i] = round(float(nestServerEmployeesMeanPowers['meanPow'][i]),1)
# C:\Users\still\AppData\Local\Temp\ipykernel_20164\2929271984.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
m1c = expressServerEmployeesMeanPowers['meanPow'].mean()
m2c = nestServerEmployeesMeanPowers['meanPow'].mean()
m3c = fastifyServerEmployeesMeanPowers['meanPow'].mean()
m4c = koaServerEmployeesMeanPowers['meanPow'].mean()
m1s = expressClientEmployeesMeanPowers['meanPow'].mean()
m2s = nestClientEmployeesMeanPowers['meanPow'].mean()
m3s = fastifyClientEmployeesMeanPowers['meanPow'].mean()
m4s = koaClientEmployeesMeanPowers['meanPow'].mean()

d = {'experiment': ["Express", "Nest", "Fastify", "Koa"],
     'meanPowServer': [m1c, m2c, m3c, m4c],
     'meanPowClient': [m1s, m2s, m3s, m4s]}
df = pd.DataFrame(data=d)

# %%
df4 = df
df4 = pd.melt(df4, id_vars="experiment", var_name="means", value_name="Mean power")
df4
# Out:
#   experiment          means  Mean power
# 0    Express  meanPowServer    2.277419
# 1       Nest  meanPowServer    2.300000
# 2    Fastify  meanPowServer    2.238710
# 3        Koa  meanPowServer    2.248387
# 4    Express  meanPowClient    2.235484
# 5       Nest  meanPowClient    2.216129
# 6    Fastify  meanPowClient    2.238710
# 7        Koa  meanPowClient    2.212903

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.set_context("talk")
ax = sns.barplot(x="experiment", y="Mean power", hue="means",
            palette={'meanPowServer': 'white', 'meanPowClient': 'black'}, data=df4)
for bar_group, desaturate_value in zip(ax.containers, [0.5, 1]):
    for bar, color in zip(bar_group, my_pal2):
        bar.set_facecolor(sns.desaturate(color, desaturate_value))

hatches = ["///", ""]
for bars, hatch in zip(ax.containers, hatches):
    for bar in bars:
        bar.set_hatch(hatch)
        
plt.title("Mean power Client vs Server (Employees)")
plt.xlabel("Experiment Type")
plt.ylabel("Mean Power (W)")

handles, labels = ax.get_legend_handles_labels()

from matplotlib.legend_handler import HandlerTuple
ax.legend(handles=[tuple(bar_group) for bar_group in ax.containers],
          labels=['Server', 'Client'],
          handlelength=4, handler_map={tuple: HandlerTuple(ndivide=None, pad=0.1)},  loc='lower right')

# Add values on top of the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.3f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.show()

# %%
################ DEPARTMENTS ################

# %%
dataDir = '/Users/still/Downloads/Exported'

# Powers
expressServerDepartmentsMeanPowers = pd.read_csv(dataDir + '/expressServerDepartmentsMeanPowers.csv', sep=',', decimal= ',')
nestServerDepartmentsMeanPowers = pd.read_csv(dataDir + '/nestServerDepartmentsMeanPowers.csv', sep=',', decimal= ',')
fastifyServerDepartmentsMeanPowers = pd.read_csv(dataDir + '/fastifyServerDepartmentsMeanPowers.csv', sep=',', decimal= ',')
koaServerDepartmentsMeanPowers = pd.read_csv(dataDir + '/koaServerDepartmentsMeanPowers.csv', sep=',', decimal= ',')

expressClientDepartmentsMeanPowers = pd.read_csv(dataDir + '/expressClientDepartmentsMeanPowers.csv', sep=',', decimal= ',')
nestClientDepartmentsMeanPowers = pd.read_csv(dataDir + '/nestClientDepartmentsMeanPowers.csv', sep=',', decimal= ',')
fastifyClientDepartmentsMeanPowers = pd.read_csv(dataDir + '/fastifyClientDepartmentsMeanPowers.csv', sep=',', decimal= ',')
koaClientDepartmentsMeanPowers = pd.read_csv(dataDir + '/koaClientDepartmentsMeanPowers.csv', sep=',', decimal= ',')

my_pal = {"Express":"#4287f5", "Nest":"#ff9f0f", "Fastify":"#03a341", "Koa":"#fa344f"}
my_pal2 = ["#4287f5", "#ff9f0f", "#03a341", "#fa344f"]

expressServerDepartmentsMeanPowers
# Out:
#                meanPow  run
# 0    2.171641791044777    1
# 1    2.163636363636364    2
# 2     2.22910447761194    3
# 3   2.1574626865671642    4
# 4   2.1867647058823536    5
# 5    2.205223880597016    6
# 6    2.161940298507463    7
# 7   2.1919117647058832    8
# 8   2.1455223880597023    9
# 9    2.262878787878788   10
# 10  2.1113636363636368   11
# 11   2.148484848484849   12
# 12  2.1625000000000005   13
# 13   2.198507462686568   14
# 14  2.2174242424242427   15
# 15  2.1235294117647063   16
# 16  2.1931818181818192   17
# 17   2.151470588235295   18
# 18   2.160606060606061   19
# 19  2.1485074626865677   20
# 20  2.1401515151515156   21
# 21  2.2171641791044783   22
# 22  2.1507462686567167   23
# 23   2.126119402985075   24
# 24   2.137878787878788   25
# 25   2.193283582089553   26
# 26  2.1939393939393947   27
# 27  2.1463235294117653   28
# 28   2.181818181818182   29
# 29  2.1962121212121217   30
# 30  2.1404411764705893   31

# %%
for i in range (0, 31):
    expressServerDepartmentsMeanPowers['meanPow'][i] = round(float(expressServerDepartmentsMeanPowers['meanPow'][i]),1)
    nestServerDepartmentsMeanPowers['meanPow'][i] = round(float(nestServerDepartmentsMeanPowers['meanPow'][i]),1)
    fastifyServerDepartmentsMeanPowers['meanPow'][i] = round(float(fastifyServerDepartmentsMeanPowers['meanPow'][i]),1)
    koaServerDepartmentsMeanPowers['meanPow'][i] = round(float(koaServerDepartmentsMeanPowers['meanPow'][i]),1)
    expressClientDepartmentsMeanPowers['meanPow'][i] = round(float(expressClientDepartmentsMeanPowers['meanPow'][i]),1)
    nestClientDepartmentsMeanPowers['meanPow'][i] = round(float(nestClientDepartmentsMeanPowers['meanPow'][i]),1)
    fastifyClientDepartmentsMeanPowers['meanPow'][i] = round(float(fastifyClientDepartmentsMeanPowers['meanPow'][i]),1)
    koaClientDepartmentsMeanPowers['meanPow'][i] = round(float(koaClientDepartmentsMeanPowers['meanPow'][i]),1)
    
expressServerDepartmentsMeanPowers
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_20164\2016558612.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expressServerDepartmentsMeanPowers['meanPow'][i] = round(float(expressServerDepartmentsMeanPowers['meanPow'][i]),1)
# C:\Users\still\AppData\Local\Temp\ipykernel_20164\2016558612.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nestServerDepartmentsMeanPowers['meanPow'][i] = round(float(nestServerDepartmentsMeanPowers['meanPow'][i]),1)
# C:\Users\still\AppData\Local\Temp\ipykernel_20164\2016558612.py:4: SettingWithCopyWarning:
# ...

# %%
m1c = expressServerDepartmentsMeanPowers['meanPow'].mean()
m2c = nestServerDepartmentsMeanPowers['meanPow'].mean()
m3c = fastifyServerDepartmentsMeanPowers['meanPow'].mean()
m4c = koaServerDepartmentsMeanPowers['meanPow'].mean()
m1s = expressClientDepartmentsMeanPowers['meanPow'].mean()
m2s = nestClientDepartmentsMeanPowers['meanPow'].mean()
m3s = fastifyClientDepartmentsMeanPowers['meanPow'].mean()
m4s = koaClientDepartmentsMeanPowers['meanPow'].mean()

d = {'experiment': ["Express", "Nest", "Fastify", "Koa"],
     'meanPowServer': [m1c, m2c, m3c, m4c],
     'meanPowClient': [m1s, m2s, m3s, m4s]}
df = pd.DataFrame(data=d)

# %%
df5 = df
df5 = pd.melt(df5, id_vars="experiment", var_name="means", value_name="Mean power")
df5
# Out:
#   experiment          means  Mean power
# 0    Express  meanPowServer    2.170968
# 1       Nest  meanPowServer    2.206452
# 2    Fastify  meanPowServer    2.167742
# 3        Koa  meanPowServer    2.177419
# 4    Express  meanPowClient    2.145161
# 5       Nest  meanPowClient    2.161290
# 6    Fastify  meanPowClient    2.112903
# 7        Koa  meanPowClient    2.122581

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.set_context("talk")
ax = sns.barplot(x="experiment", y="Mean power", hue="means",
            palette={'meanPowServer': 'white', 'meanPowClient': 'black'}, data=df5)
for bar_group, desaturate_value in zip(ax.containers, [0.5, 1]):
    for bar, color in zip(bar_group, my_pal2):
        bar.set_facecolor(sns.desaturate(color, desaturate_value))

hatches = ["///", ""]
for bars, hatch in zip(ax.containers, hatches):
    for bar in bars:
        bar.set_hatch(hatch)
        
plt.title("Mean power Client vs Server (Departments)")
plt.xlabel("Experiment Type")
plt.ylabel("Mean Power (W)")

handles, labels = ax.get_legend_handles_labels()

from matplotlib.legend_handler import HandlerTuple
ax.legend(handles=[tuple(bar_group) for bar_group in ax.containers],
          labels=['Server', 'Client'],
          handlelength=4, handler_map={tuple: HandlerTuple(ndivide=None, pad=0.1)},  loc='lower right')

# Add values on top of the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.3f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.show()

# %%
################ TIME ################

# %%
################ EMPLOYEES ################

# %%
dataDir = '/Users/still/Downloads/Exported'

# Times
expressServerEmployeesTimes = pd.read_csv(dataDir + '/expressServerEmployeesTimes.csv', sep=',', decimal= ',')
nestServerEmployeesTimes = pd.read_csv(dataDir + '/nestServerEmployeesTimes.csv', sep=',', decimal= ',')
fastifyServerEmployeesTimes = pd.read_csv(dataDir + '/fastifyServerEmployeesTimes.csv', sep=',', decimal= ',')
koaServerEmployeesTimes = pd.read_csv(dataDir + '/koaServerEmployeesTimes.csv', sep=',', decimal= ',')

expressClientEmployeesTimes = pd.read_csv(dataDir + '/expressClientEmployeesTimes.csv', sep=',', decimal= ',')
nestClientEmployeesTimes = pd.read_csv(dataDir + '/nestClientEmployeesTimes.csv', sep=',', decimal= ',')
fastifyClientEmployeesTimes = pd.read_csv(dataDir + '/fastifyClientEmployeesTimes.csv', sep=',', decimal= ',')
koaClientEmployeesTimes = pd.read_csv(dataDir + '/koaClientEmployeesTimes.csv', sep=',', decimal= ',')

my_pal = {"Express":"#4287f5", "Nest":"#ff9f0f", "Fastify":"#03a341", "Koa":"#fa344f"}
my_pal2 = ["#4287f5", "#ff9f0f", "#03a341", "#fa344f"]

expressServerEmployeesTimes
# Out:
#     time  run
# 0     30    1
# 1     30    2
# 2     31    3
# 3     30    4
# 4     30    5
# 5     30    6
# 6     30    7
# 7     30    8
# 8     30    9
# 9     30   10
# 10    29   11
# 11    29   12
# 12    29   13
# 13    30   14
# 14    29   15
# 15    30   16
# 16    30   17
# 17    29   18
# 18    30   19
# 19    30   20
# 20    27   21
# 21    27   22
# 22    28   23
# 23    28   24
# 24    28   25
# 25    27   26
# 26    28   27
# 27    28   28
# 28    27   29
# 29    26   30
# 30    26   31

# %%
for i in range (0, 31):
    expressServerEmployeesTimes['time'][i] = round(float(expressServerEmployeesTimes['time'][i]),1)
    nestServerEmployeesTimes['time'][i] = round(float(nestServerEmployeesTimes['time'][i]),1)
    fastifyServerEmployeesTimes['time'][i] = round(float(fastifyServerEmployeesTimes['time'][i]),1)
    koaServerEmployeesTimes['time'][i] = round(float(koaServerEmployeesTimes['time'][i]),1)
    expressClientEmployeesTimes['time'][i] = round(float(expressClientEmployeesTimes['time'][i]),1)
    nestClientEmployeesTimes['time'][i] = round(float(nestClientEmployeesTimes['time'][i]),1)
    fastifyClientEmployeesTimes['time'][i] = round(float(fastifyClientEmployeesTimes['time'][i]),1)
    koaClientEmployeesTimes['time'][i] = round(float(koaClientEmployeesTimes['time'][i]),1)
    
expressServerEmployeesTimes
# Out:
#     time  run
# 0     30    1
# 1     30    2
# 2     31    3
# 3     30    4
# 4     30    5
# 5     30    6
# 6     30    7
# 7     30    8
# 8     30    9
# 9     30   10
# 10    29   11
# 11    29   12
# 12    29   13
# 13    30   14
# 14    29   15
# 15    30   16
# 16    30   17
# 17    29   18
# 18    30   19
# 19    30   20
# 20    27   21
# 21    27   22
# 22    28   23
# 23    28   24
# 24    28   25
# 25    27   26
# 26    28   27
# 27    28   28
# 28    27   29
# 29    26   30
# 30    26   31

# %%
m1c = expressServerEmployeesTimes['time'].mean()
m2c = nestServerEmployeesTimes['time'].mean()
m3c = fastifyServerEmployeesTimes['time'].mean()
m4c = koaServerEmployeesTimes['time'].mean()
m1s = expressClientEmployeesTimes['time'].mean()
m2s = nestClientEmployeesTimes['time'].mean()
m3s = fastifyClientEmployeesTimes['time'].mean()
m4s = koaClientEmployeesTimes['time'].mean()

d = {'experiment': ["Express", "Nest", "Fastify", "Koa"],
     'meanTimeServer': [m1c, m2c, m3c, m4c],
     'meanTimeClient': [m1s, m2s, m3s, m4s]}
df = pd.DataFrame(data=d)

# %%
df6 = df
df6 = pd.melt(df6, id_vars="experiment", var_name="means", value_name="Mean time")
df6
# Out:
#   experiment           means  Mean time
# 0    Express  meanTimeServer  28.903226
# 1       Nest  meanTimeServer  34.580645
# 2    Fastify  meanTimeServer  30.322581
# 3        Koa  meanTimeServer  28.870968
# 4    Express  meanTimeClient  28.903226
# 5       Nest  meanTimeClient  34.580645
# 6    Fastify  meanTimeClient  30.322581
# 7        Koa  meanTimeClient  28.870968

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.set_context("talk")
ax = sns.barplot(x="experiment", y="Mean time", hue="means",
            palette={'meanTimeServer': 'white', 'meanTimeClient': 'black'}, data=df6)
for bar_group, desaturate_value in zip(ax.containers, [0.5, 1]):
    for bar, color in zip(bar_group, my_pal2):
        bar.set_facecolor(sns.desaturate(color, desaturate_value))

hatches = ["///", ""]
for bars, hatch in zip(ax.containers, hatches):
    for bar in bars:
        bar.set_hatch(hatch)
        
plt.title("Mean time Client vs Server (Employees)")
plt.xlabel("Experiment Type")
plt.ylabel("Mean Time (S)")

handles, labels = ax.get_legend_handles_labels()

from matplotlib.legend_handler import HandlerTuple
ax.legend(handles=[tuple(bar_group) for bar_group in ax.containers],
          labels=['Server', 'Client'],
          handlelength=4, handler_map={tuple: HandlerTuple(ndivide=None, pad=0.1)},  loc='lower right')

# Add values on top of the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.show()

# %%
################ DEPARTMENTS ################

# %%
dataDir = '/Users/still/Downloads/Exported'

# Times
expressServerDepartmentsTimes = pd.read_csv(dataDir + '/expressServerDepartmentsTimes.csv', sep=',', decimal= ',')
nestServerDepartmentsTimes = pd.read_csv(dataDir + '/nestServerDepartmentsTimes.csv', sep=',', decimal= ',')
fastifyServerDepartmentsTimes = pd.read_csv(dataDir + '/fastifyServerDepartmentsTimes.csv', sep=',', decimal= ',')
koaServerDepartmentsTimes = pd.read_csv(dataDir + '/koaServerDepartmentsTimes.csv', sep=',', decimal= ',')

expressClientDepartmentsTimes = pd.read_csv(dataDir + '/expressClientDepartmentsTimes.csv', sep=',', decimal= ',')
nestClientDepartmentsTimes = pd.read_csv(dataDir + '/nestClientDepartmentsTimes.csv', sep=',', decimal= ',')
fastifyClientDepartmentsTimes = pd.read_csv(dataDir + '/fastifyClientDepartmentsTimes.csv', sep=',', decimal= ',')
koaClientDepartmentsTimes = pd.read_csv(dataDir + '/koaClientDepartmentsTimes.csv', sep=',', decimal= ',')

my_pal = {"Express":"#4287f5", "Nest":"#ff9f0f", "Fastify":"#03a341", "Koa":"#fa344f"}
my_pal2 = ["#4287f5", "#ff9f0f", "#03a341", "#fa344f"]

expressServerDepartmentsTimes
# Out:
#     time  run
# 0     67    1
# 1     66    2
# 2     67    3
# 3     67    4
# 4     68    5
# 5     67    6
# 6     67    7
# 7     68    8
# 8     67    9
# 9     66   10
# 10    66   11
# 11    66   12
# 12    68   13
# 13    67   14
# 14    66   15
# 15    68   16
# 16    66   17
# 17    68   18
# 18    66   19
# 19    67   20
# 20    66   21
# 21    67   22
# 22    67   23
# 23    67   24
# 24    66   25
# 25    67   26
# 26    66   27
# 27    68   28
# 28    66   29
# 29    66   30
# 30    68   31

# %%
for i in range (0, 31):
    expressServerDepartmentsTimes['time'][i] = round(float(expressServerDepartmentsTimes['time'][i]),1)
    nestServerDepartmentsTimes['time'][i] = round(float(nestServerDepartmentsTimes['time'][i]),1)
    fastifyServerDepartmentsTimes['time'][i] = round(float(fastifyServerDepartmentsTimes['time'][i]),1)
    koaServerDepartmentsTimes['time'][i] = round(float(koaServerDepartmentsTimes['time'][i]),1)
    expressClientDepartmentsTimes['time'][i] = round(float(expressClientDepartmentsTimes['time'][i]),1)
    nestClientDepartmentsTimes['time'][i] = round(float(nestClientDepartmentsTimes['time'][i]),1)
    fastifyClientDepartmentsTimes['time'][i] = round(float(fastifyClientDepartmentsTimes['time'][i]),1)
    koaClientDepartmentsTimes['time'][i] = round(float(koaClientDepartmentsTimes['time'][i]),1)
    
expressServerDepartmentsTimes
# Out:
#     time  run
# 0     67    1
# 1     66    2
# 2     67    3
# 3     67    4
# 4     68    5
# 5     67    6
# 6     67    7
# 7     68    8
# 8     67    9
# 9     66   10
# 10    66   11
# 11    66   12
# 12    68   13
# 13    67   14
# 14    66   15
# 15    68   16
# 16    66   17
# 17    68   18
# 18    66   19
# 19    67   20
# 20    66   21
# 21    67   22
# 22    67   23
# 23    67   24
# 24    66   25
# 25    67   26
# 26    66   27
# 27    68   28
# 28    66   29
# 29    66   30
# 30    68   31

# %%
m1c = expressServerDepartmentsTimes['time'].mean()
m2c = nestServerDepartmentsTimes['time'].mean()
m3c = fastifyServerDepartmentsTimes['time'].mean()
m4c = koaServerDepartmentsTimes['time'].mean()
m1s = expressClientDepartmentsTimes['time'].mean()
m2s = nestClientDepartmentsTimes['time'].mean()
m3s = fastifyClientDepartmentsTimes['time'].mean()
m4s = koaClientDepartmentsTimes['time'].mean()

d = {'experiment': ["Express", "Nest", "Fastify", "Koa"],
     'meanTimeServer': [m1c, m2c, m3c, m4c],
     'meanTimeClient': [m1s, m2s, m3s, m4s]}
df = pd.DataFrame(data=d)

# %%
df7 = df
df7 = pd.melt(df7, id_vars="experiment", var_name="means", value_name="Mean time")
df7
# Out:
#   experiment           means  Mean time
# 0    Express  meanTimeServer  66.838710
# 1       Nest  meanTimeServer  67.129032
# 2    Fastify  meanTimeServer  63.935484
# 3        Koa  meanTimeServer  67.064516
# 4    Express  meanTimeClient  66.838710
# 5       Nest  meanTimeClient  67.129032
# 6    Fastify  meanTimeClient  63.935484
# 7        Koa  meanTimeClient  67.064516

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.set_context("talk")
ax = sns.barplot(x="experiment", y="Mean time", hue="means",
            palette={'meanTimeServer': 'white', 'meanTimeClient': 'black'}, data=df7)
for bar_group, desaturate_value in zip(ax.containers, [0.5, 1]):
    for bar, color in zip(bar_group, my_pal2):
        bar.set_facecolor(sns.desaturate(color, desaturate_value))

hatches = ["///", ""]
for bars, hatch in zip(ax.containers, hatches):
    for bar in bars:
        bar.set_hatch(hatch)
        
plt.title("Mean time Client vs Server (Departments)")
plt.xlabel("Experiment Type")
plt.ylabel("Mean Time (S)")

handles, labels = ax.get_legend_handles_labels()

from matplotlib.legend_handler import HandlerTuple
ax.legend(handles=[tuple(bar_group) for bar_group in ax.containers],
          labels=['Server', 'Client'],
          handlelength=4, handler_map={tuple: HandlerTuple(ndivide=None, pad=0.1)},  loc='lower right')

# Add values on top of the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.show()
